# %% [markdown]
# # Shopping Mall Analysis

# %% [markdown]
# #### Import Packages

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff

# %% [markdown]
# #### Read in the data

# %%
df = pd.read_csv('customer_shopping_data.csv')

df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %% [markdown]
# ## 1. Overall sales and revenue:

# %% [markdown]
# #### The total sales for each shopping mall:

# %%
sales_by_mall = df.groupby("shopping_mall")["price"].sum().reset_index()

fig = px.bar(sales_by_mall, x="shopping_mall", y="price",
             title="Total Sales by Shopping Mall",
             labels={"shopping_mall": "Shopping Mall", "price": "Total Sales"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="388b06c4-f8d2-4ce2-bd3a-5eafcfc70f0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("388b06c4-f8d2-4ce2-bd3a-5eafcfc70f0d")) {                    Plotly.newPlot(                        "388b06c4-f8d2-4ce2-bd3a-5eafcfc70f0d",                        [{"alignmentgroup":"True","hovertemplate":"Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[3433671.84,3390408.31,3336073.82,6717077.54,13710755.24,13851737.62,10249980.07,6937992.99,3414019.46,3509649.02],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":" ...

# %% [markdown]
# #### The total sales for each shopping mall, with the bars stacked by category:

# %%
sales_by_mall = df.groupby(["shopping_mall", "category"])["price"].sum().reset_index()
fig = px.bar(sales_by_mall, x="shopping_mall", y="price", color="category",
             title="Total Sales by Shopping Mall and Category",
             labels={"shopping_mall": "Shopping Mall", "price": "Total Sales", "category": "Category"},
             barmode="stack")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="db474e86-c341-4f16-b2a3-6f9c9ff7601d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db474e86-c341-4f16-b2a3-6f9c9ff7601d")) {                    Plotly.newPlot(                        "db474e86-c341-4f16-b2a3-6f9c9ff7601d",                        [{"alignmentgroup":"True","hovertemplate":"Category=Books<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Books","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Books","offsetgroup":"Books","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[11998.800000000001,11059.5,11453.4,20725.2,44980.35,46949.85,34405.65,22240.2,10908.0,12256.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Clothing<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Clothing","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Clothing","offsetgroup":"Clothing","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[1554414.4,1511803.04,1572119.12,3050313.2,6155541.04,6245565.04,4719958.32,3166444.16,1530708.08,1568818.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Cosmetics<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Cosmetics","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cosmetics","offsetgroup":"Cosmetics","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[88394.84,92379.52,95225.72,178741.36,372242.3,373787.38,272422.0,185775.54,92664.14,96974.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Food & Beverage<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Food & Beverage","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Food & Beverage","offsetgroup":"Food & Beverage","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[11992.39,11030.07,10836.56,23419.94,45474.85,46431.94,35375.72,23984.78,11432.78,11589.68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Shoes<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Shoes","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"xaxis":"x","y":[884050.4099999999,871446.84,875648.0299999999,1806511.7,3640031.05,3668239.04,2610139.33,1942750.2899999998,882850.07,953670.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Souvenir<br>Shopping Mall=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Souvenir","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Souvenir","offsetgroup":"Souvenir","orientation":"v","showlegend":true,"textposition":"auto","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outle ...

# %% [markdown]
# #### The total sales for each category and shopping mall:

# %%
sales_by_category_mall = df.groupby(["category", "shopping_mall"])["price"].sum().reset_index()

fig = px.bar(sales_by_category_mall, x="category", y="price", color="shopping_mall",
             title="Total Sales by Category and Shopping Mall",
             labels={"category": "Category", "price": "Total Sales", "shopping_mall": "Shopping Mall"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a47ead0f-2355-432f-8bc9-b34d5f20097f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a47ead0f-2355-432f-8bc9-b34d5f20097f")) {                    Plotly.newPlot(                        "a47ead0f-2355-432f-8bc9-b34d5f20097f",                        [{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Cevahir AVM<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Cevahir AVM","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cevahir AVM","offsetgroup":"Cevahir AVM","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[11998.800000000001,1554414.4,88394.84,11992.39,884050.4099999999,8304.84,819000.0,55516.16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Emaar Square Mall<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Emaar Square Mall","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Emaar Square Mall","offsetgroup":"Emaar Square Mall","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[11059.5,1511803.04,92379.52,11030.07,871446.84,8515.98,834750.0,49423.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Forum Istanbul<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Forum Istanbul","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Forum Istanbul","offsetgroup":"Forum Istanbul","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[11453.4,1572119.12,95225.72,10836.56,875648.0299999999,9090.75,706650.0,55050.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Istinye Park<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Istinye Park","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Istinye Park","offsetgroup":"Istinye Park","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[20725.2,3050313.2,178741.36,23419.94,1806511.7,18369.18,1509900.0,109096.96],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Kanyon<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Kanyon","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Kanyon","offsetgroup":"Kanyon","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[44980.35,6155541.04,372242.3,45474.85,3640031.05,35483.25,3202500.0,214502.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Mall of Istanbul<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Mall of Istanbul","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mall of Istanbul","offsetgroup":"Mall of Istanbul","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[46949.85,6245565.04,373787.38,46431.94,3668239.04,34263.33,3220350.0,216151.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Metrocity<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Metrocity","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Metrocity","offsetgroup":"Metrocity","orientation":"v" ...

# %% [markdown]
# #### The total sales by category and shopping mall:

# %%
sales_by_category_mall = df.groupby(["category", "shopping_mall"])["price"].sum().reset_index()

fig = px.imshow(sales_by_category_mall.pivot("category", "shopping_mall", "price"),
                color_continuous_scale="YlGnBu",
                title="Total Sales by Category and Shopping Mall",
                labels={"x": "Shopping Mall", "y": "Category", "color": "Total Sales"})
fig.show()
# Out:
# <ipython-input-6-7443d5e88978>:3: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="47778199-ccd5-4350-9639-5ae114453bb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47778199-ccd5-4350-9639-5ae114453bb7")) {                    Plotly.newPlot(                        "47778199-ccd5-4350-9639-5ae114453bb7",                        [{"coloraxis":"coloraxis","name":"0","x":["Cevahir AVM","Emaar Square Mall","Forum Istanbul","Istinye Park","Kanyon","Mall of Istanbul","Metrocity","Metropol AVM","Viaport Outlet","Zorlu Center"],"y":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"z":[[11998.800000000001,11059.5,11453.4,20725.2,44980.35,46949.85,34405.65,22240.2,10908.0,12256.35],[1554414.4,1511803.04,1572119.12,3050313.2,6155541.04,6245565.04,4719958.32,3166444.16,1530708.08,1568818.24],[88394.84,92379.52,95225.72,178741.36,372242.3,373787.38,272422.0,185775.54,92664.14,96974.1],[11992.39,11030.07,10836.56,23419.94,45474.85,46431.94,35375.72,23984.78,11432.78,11589.68],[884050.4099999999,871446.84,875648.0299999999,1806511.7,3640031.05,3668239.04,2610139.33,1942750.2899999998,882850.07,953670.13],[8304.84,8515.98,9090.75,18369.18,35483.25,34263.33,25770.81,18603.78,7636.23,8398.68],[819000.0,834750.0,706650.0,1509900.0,3202500.0,3220350.0,2386650.0,1465800.0,823200.0,803250.0],[55516.16,49423.36,55050.24,109096.96,214502.4,216151.04,165258.24,112394.24,54620.16,54691.840000000004]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Shopping Mall: %{x}<br>Category: %{y}<br>Total Sales: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %% [markdown]
# #### The total sales by month:

# %%
df["invoice_date"] = pd.to_datetime(df["invoice_date"])
monthly_sales = df.groupby(pd.Grouper(key="invoice_date", freq="M"))["price"].sum().reset_index()
fig = px.line(monthly_sales, x="invoice_date", y="price",
              title="Total Sales by Month",
              labels={"invoice_date": "Month", "price": "Total Sales"})
fig.show()
# Out:
# <ipython-input-7-057648308b94>:1: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f6a3b28b-06f8-4400-84b9-8383dd69ef1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6a3b28b-06f8-4400-84b9-8383dd69ef1e")) {                    Plotly.newPlot(                        "f6a3b28b-06f8-4400-84b9-8383dd69ef1e",                        [{"hovertemplate":"Month=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00","2023-10-31T00:00:00","2023-11-30T00:00:00","2023-12-31T00:00:00"],"xaxis":"x","y":[2576821.6,2374882.12,2755492.75,2647497.76,2678394.69,2566936.55,2767499.65,2584867.89,2477456.71,2738863.73,2499835.01,2647756.17,2700665.69,2379247.27,2687567.35,2589770.93,2679964.45,2635905.48,2649167.06,2576463.43,2596237.64,2727594.65,2478523.81,2671718.42,1796920.94,1775770.1099999999,246276.5,276995.69,257420.54,301680.27,256520.43,252117.95,194996.06,207778.8,142045.13999999998,153712.66999999998],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %% [markdown]
# #### The monthly revenue by Shopping Mall:

# %%
df["invoice_date"] = pd.to_datetime(df["invoice_date"])  # Convert "invoice_date" column to datetime type

monthly_revenue_by_mall = df.groupby([pd.Grouper(key='invoice_date', freq='M'), "shopping_mall"])["price"].sum().reset_index()

fig = px.line(monthly_revenue_by_mall, x="invoice_date", y="price", color="shopping_mall",
              title="Monthly Revenue by Shopping Mall",
              labels={"invoice_date": "Date", "price": "Revenue", "shopping_mall": "Shopping Mall"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b7c74a46-776a-45e3-9648-8054c0bb7878" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7c74a46-776a-45e3-9648-8054c0bb7878")) {                    Plotly.newPlot(                        "b7c74a46-776a-45e3-9648-8054c0bb7878",                        [{"hovertemplate":"Shopping Mall=Cevahir AVM<br>Date=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Cevahir AVM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cevahir AVM","orientation":"v","showlegend":true,"x":["2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00","2023-10-31T00:00:00","2023-11-30T00:00:00","2023-12-31T00:00:00"],"xaxis":"x","y":[144567.01,98425.51,153080.45,142063.16,135814.13,106047.81999999999,129752.11,118747.09999999999,149370.7,129393.98,128882.22,140322.22,136089.66,150443.59,131477.37,144670.3,145036.0,117703.9,108661.59999999999,139878.66,153738.03,104660.07,128140.24,114498.25,82279.95999999999,87400.79,15611.09,14195.64,12960.92,19246.32,11295.199999999999,16278.439999999999,7092.32,5079.35,4435.24,6332.49],"yaxis":"y","type":"scatter"},{"hovertemplate":"Shopping Mall=Emaar Square Mall<br>Date=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Emaar Square Mall","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Emaar Square Mall","orientation":"v","showlegend":true,"x":["2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00","2023-10-31T00:00:00","2023-11-30T00:00:00","2023-12-31T00:00:00"],"xaxis":"x","y":[130891.84,112723.93,152182.23,127666.73,137976.15,127803.68,159926.18,102102.03,137421.34,162935.2,119221.34,157102.0,140212.46,86511.37,130019.69,121502.64,126849.99,127312.53,124973.15,119737.99,116382.70999999999,154258.14,87299.09999999999,151634.18,100282.95999999999,70155.97,9664.51,6422.78,14413.97,15266.38,9128.78,9659.48,12057.61,6926.030000000001,9705.65,12077.589999999998],"yaxis":"y","type":"scatter"},{"hovertemplate":"Shopping Mall=Forum Istanbul<br>Date=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Forum Istanbul","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Forum Istanbul","orientation":"v","showlegend":true,"x":["2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T0 ...

# %% [markdown]
# ## 2. Sales breakdown by category:

# %% [markdown]
# #### Breakdown of sales by category, broken down by gender:

# %%
sales_by_category_gender = df.groupby(["category", "gender"])["price"].sum().reset_index()

fig = px.sunburst(sales_by_category_gender, path=["gender", "category"], values="price",
                  title="Breakdown of Sales by Category and Gender",
                  labels={"gender": "Gender", "category": "Category", "price": "Total Sales"})

fig.update_layout(width=1000, height=800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a45dfde2-87e7-4ba3-9a00-b1a1e192c7c0" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a45dfde2-87e7-4ba3-9a00-b1a1e192c7c0")) {                    Plotly.newPlot(                        "a45dfde2-87e7-4ba3-9a00-b1a1e192c7c0",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Total Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Female/Books","Male/Books","Female/Clothing","Male/Clothing","Female/Cosmetics","Male/Cosmetics","Female/Food & Beverage","Male/Food & Beverage","Female/Shoes","Male/Shoes","Female/Souvenir","Male/Souvenir","Female/Technology","Male/Technology","Female/Toys","Male/Toys","Female","Male"],"labels":["Books","Books","Clothing","Clothing","Cosmetics","Cosmetics","Food & Beverage","Food & Beverage","Shoes","Shoes","Souvenir","Souvenir","Technology","Technology","Toys","Toys","Female","Male"],"name":"","parents":["Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","",""],"values":[132956.4,94020.90000000001,18616663.12,12459021.52,1108432.26,740174.64,137873.26,93695.45,10746644.02,7388692.87,105288.48,69148.35,9425850.0,6346200.0,658094.08,428610.56,40931801.62,27619564.29],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888 ...

# %% [markdown]
# #### The total sales for each category, with the bars colored by payment method:

# %%
sales_by_category = df.groupby(["category", "payment_method"])["price"].sum().reset_index()

fig = px.bar(sales_by_category, x="category", y="price", color="payment_method",
             title="Total Sales by Category and Payment Method",
             labels={"category": "Category", "price": "Total Sales", "payment_method": "Payment Method"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="13486dd8-4aeb-40b1-a08b-b7afed241f72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13486dd8-4aeb-40b1-a08b-b7afed241f72")) {                    Plotly.newPlot(                        "13486dd8-4aeb-40b1-a08b-b7afed241f72",                        [{"alignmentgroup":"True","hovertemplate":"Payment Method=Cash<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Cash","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cash","offsetgroup":"Cash","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[103489.65000000001,13966323.36,810394.46,102628.29000000001,8097493.64,76080.78,7056000.0,492620.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=Credit Card<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Credit Card","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Credit Card","offsetgroup":"Credit Card","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[76689.3,10765970.16,662066.78,82592.16,6433222.2299999995,62380.14,5586000.0,382556.16000000003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=Debit Card<br>Category=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Debit Card","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Debit Card","offsetgroup":"Debit Card","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[46798.35,6343391.12,376145.66,46348.26,3604621.02,35975.909999999996,3130050.0,211527.68],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222 ...

# %% [markdown]
# #### The distribution of price by category:

# %%
fig = px.box(df, x="category", y="price", color="category",
             title="Distribution of Price by Category",
             labels={"category": "Category", "price": "Price"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8ca59e3b-6e88-4403-8adb-fd37ae01e472" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ca59e3b-6e88-4403-8adb-fd37ae01e472")) {                    Plotly.newPlot(                        "8ca59e3b-6e88-4403-8adb-fd37ae01e472",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"Clothing","marker":{"color":"#636efa"},"name":"Clothing","notched":false,"offsetgroup":"Clothing","orientation":"v","showlegend":true,"x":["Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing", ...

# %% [markdown]
# #### Quantity sold by category:
#
# > In this context, density refers to the probability density function of the distribution of quantity sold by category. It is a measure of how the probability mass is spread over the range of values for the quantity sold.

# %%
hist_data = [df[df["category"]=="Clothing"]["quantity"], df[df["category"]=="Technology"]["quantity"], df[df["category"]=="Shoes"]["quantity"], df[df["category"]=="Books"]["quantity"]]

group_labels = ["Clothing", "Technology", "Shoes", "Books"]

fig = ff.create_distplot(hist_data, group_labels, show_hist=False, show_rug=False)

fig.update_layout(title="Distribution of Quantity Sold by Category",
xaxis_title="Quantity",
yaxis_title="Density")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
016,3.024,3.032,3.04,3.048,3.056,3.064,3.072,3.08,3.088,3.096,3.104,3.112,3.12,3.128,3.136,3.144,3.152,3.16,3.168,3.176,3.184,3.192,3.2,3.208,3.216,3.224,3.232,3.24,3.248,3.256,3.264,3.272,3.28,3.288,3.296,3.304,3.312,3.32,3.328,3.336,3.344,3.352,3.36,3.368,3.376,3.384,3.392,3.4,3.408,3.416,3.424,3.432,3.44,3.448,3.456,3.464,3.472,3.48,3.488,3.496,3.504,3.512,3.52,3.528,3.536,3.544,3.552,3.56,3.568,3.576,3.584,3.592,3.6,3.608,3.616,3.624,3.632,3.64,3.648,3.656,3.664,3.672,3.68,3.688,3.696,3.704,3.712,3.72,3.728,3.736,3.744,3.752,3.76,3.768,3.776,3.784,3.792,3.8,3.808,3.816,3.824,3.832,3.84,3.848,3.856,3.864,3.872,3.88,3.888,3.896,3.904,3.912,3.92,3.928,3.936,3.944,3.952,3.96,3.968,3.976,3.984,3.992,4.0,4.008,4.016,4.024,4.032,4.04,4.048,4.056,4.064,4.072,4.08,4.088,4.096,4.104,4.112,4.12,4.128,4.136,4.144,4.152,4.16,4.168,4.176,4.184,4.192,4.2,4.208,4.216,4.224,4.232,4.24,4.248,4.256,4.263999999999999,4.272,4.279999999999999,4.288,4.295999999999999,4.304,4.311999999999999,4.32,4.327999999999999,4.336,4.343999999999999,4.352,4.359999999999999,4.368,4.3759999999999994,4.384,4.3919999999999995,4.4,4.4079999999999995,4.416,4.4239999999999995,4.432,4.4399999999999995,4.448,4.4559999999999995, ...

# %% [markdown]
# #### Sales by category and day of the week:

# %%
df["invoice_date"] = pd.to_datetime(df["invoice_date"])
df["day_of_week"] = df["invoice_date"].dt.day_name()

sales_by_category_day = df.groupby(["category", "day_of_week"])["price"].sum().reset_index()

fig = px.line(sales_by_category_day, x="day_of_week", y="price", color="category",
              title="Total Sales by Category and Day of the Week",
              labels={"day_of_week": "Day of the Week", "price": "Total Sales", "category": "Category"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2d0732da-d70e-41f5-b7fb-4310ee7c334b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d0732da-d70e-41f5-b7fb-4310ee7c334b")) {                    Plotly.newPlot(                        "2d0732da-d70e-41f5-b7fb-4310ee7c334b",                        [{"hovertemplate":"Category=Books<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Books","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Books","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[34890.450000000004,32905.8,33254.25,31163.55,32739.15,32163.45,29860.65],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Clothing<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Clothing","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Clothing","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[4456488.08,4578920.72,4508101.84,4209522.24,4460089.04,4483195.2,4379367.52],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Cosmetics<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Cosmetics","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cosmetics","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[270754.94,272909.92,253474.44,265997.72,259695.41999999998,263802.08,261972.38],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Food & Beverage<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Food & Beverage","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Food & Beverage","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[32441.69,32839.17,33592.29,33597.52,33111.13,32807.79,33179.12],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Shoes<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Shoes","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Shoes","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[2589133.38,2714568.9099999997,2570528.11,2569927.94,2522514.51,2584932.19,2583731.85],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Souvenir<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Souvenir","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Souvenir","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[28022.97,24609.54,24691.65,23882.28,23659.41,25876.38,23694.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Technology<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Technology","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Technology","orientation":"v","showlegend":true,"x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[2367750.0,2387700.0,2411850.0,2070600.0,2208150.0,2085300.0,2240700.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Toys<br>Day of the Week=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Toys","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Toys","orientation":"v", ...

# %% [markdown]
# #### Average price per unit by category and shopping mall:

# %%
avg_price_by_category_mall = df.groupby(["category", "shopping_mall"])["price"].mean().reset_index()

fig = px.bar(avg_price_by_category_mall, x="category", y="price", color="shopping_mall",
             title="Average Price per Unit by Category and Shopping Mall",
             labels={"category": "Category", "price": "Average Price per Unit", "shopping_mall": "Shopping Mall"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="84350be0-fe93-44de-8199-e436313347be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84350be0-fe93-44de-8199-e436313347be")) {                    Plotly.newPlot(                        "84350be0-fe93-44de-8199-e436313347be",                        [{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Cevahir AVM<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Cevahir AVM","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cevahir AVM","offsetgroup":"Cevahir AVM","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[46.50697674418605,899.0251012145749,120.7579781420765,15.534183937823833,1804.1845102040816,34.603500000000004,3199.21875,108.00809338521401],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Emaar Square Mall<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Emaar Square Mall","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Emaar Square Mall","offsetgroup":"Emaar Square Mall","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[46.86228813559322,915.689303452453,121.552,15.939407514450867,1749.893253012048,34.477651821862345,3173.9543726235743,106.51586206896552],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Forum Istanbul<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Forum Istanbul","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Forum Istanbul","offsetgroup":"Forum Istanbul","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[45.449999999999996,909.2649624060151,123.66976623376624,15.219887640449437,1911.8952620087334,34.83045977011494,3019.871794871795,103.67276836158192],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Istinye Park<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Istinye Park","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Istinye Park","offsetgroup":"Istinye Park","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[44.85974025974026,909.7265732180138,122.59352537722907,15.718080536912751,1804.706993006993,35.66831067961165,3100.4106776180697,107.48468965517242],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Kanyon<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Kanyon","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Kanyon","offsetgroup":"Kanyon","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[44.40310957551826,899.9329005847953,123.13671849156466,15.632468202131315,1804.6757808626671,34.217213114754095,3212.136409227683,107.95289380976347],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shopping Mall=Mall of Istanbul<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Mall of Istanbul","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mall of Istanbul","offsetgroup":"Mall of Istanbul","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology ...

# %% [markdown]
# #### Average price per unit by category and payment method:

# %%
avg_price_by_category_payment = df.groupby(["category", "payment_method"])["price"].mean().reset_index()

fig = px.bar(avg_price_by_category_payment, x="category", y="price", color="payment_method",
             title="Average Price per Unit by Category and Payment Method",
             labels={"category": "Category", "price": "Average Price per Unit", "payment_method": "Payment Method"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d6fe84fb-97d1-4800-808c-d086e76b9f7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6fe84fb-97d1-4800-808c-d086e76b9f7c")) {                    Plotly.newPlot(                        "d6fe84fb-97d1-4800-808c-d086e76b9f7c",                        [{"alignmentgroup":"True","hovertemplate":"Payment Method=Cash<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Cash","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cash","offsetgroup":"Cash","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[45.63035714285715,903.6182298136646,121.425600839077,15.580429634127828,1809.9002324541796,34.41012211668928,3157.046979865772,108.4590048436812],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=Credit Card<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Credit Card","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Credit Card","offsetgroup":"Credit Card","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[45.21774764150943,895.2989738045738,124.07548350824588,15.73184,1810.6451533915001,35.24301694915254,3186.5373645179693,107.82304396843293],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=Debit Card<br>Category=%{x}<br>Average Price per Unit=%{y}<extra></extra>","legendgroup":"Debit Card","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Debit Card","offsetgroup":"Debit Card","orientation":"v","showlegend":true,"textposition":"auto","x":["Books","Clothing","Cosmetics","Food & Beverage","Shoes","Souvenir","Technology","Toys"],"xaxis":"x","y":[46.01607669616519,905.4226548672566,121.8482863621639,15.770078257910855,1796.0244245142003,35.33979371316306,3105.2083333333335,105.9227240861292],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{ ...

# %% [markdown]
# ## 3. Customer demographics:

# %% [markdown]
# #### Customer ages, colored by gender:

# %%
fig = px.histogram(df, x="age", color="gender",
                   title="Age Distribution by Gender",
                   labels={"age": "Age", "gender": "Gender", "count": "Count"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="83c27028-b151-446f-8215-a914a2ccb9f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83c27028-b151-446f-8215-a914a2ccb9f2")) {                    Plotly.newPlot(                        "83c27028-b151-446f-8215-a914a2ccb9f2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=Female<br>Age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"x":[28,66,53,28,49,32,60,36,29,67,67,42,46,27,42,25,65,66,32,66,59,49,48,40,41,19,43,22,61,41,53,43,45,29,19,67,36,33,33,29,63,24,24,44,47,57,40,69,47,53,66,52,43,59,30,25,29,19,33,26,40,24,30,64,57,26,19,22,56,60,32,56,68,64,60,41,29,60,42,50,45,40,32,28,22,21,31,61,67,48,53,28,43,59,32,41,30,51,23,24,61,25,66,59,26,59,53,23,66,56,38,44,26,41,23,31,56,34,29,20,54,32,41,67,38,38,56,37,19,53,69,31,34,20,18,34,61,38,67,63,21,41,48,22,54,51,29,44,20,59,23,25,56,54,53,62,42,68,52,19,68,33,60,24,52,67,50,58,50,68,59,66,52,27,43,19,23,52,20,29,50,44,47,48,39,34,65,53,19,19,31,43,34,32,28,48,46,20,35,22,52,45,41,57,60,44,50,19,54,63,66,48,64,20,31,44,42,67,55,62,54,43,30,58,49,19,58,49,50,21,23,69,45,50,45,47,36,61,46,38,41,58,53,63,54,54,62,18,44,20,65,63,57,59,44,63,68,21,33,23,49,54,41,21,45,58,53,21,51,50,31,29,33,66,22,55,43,22,27,68,48,56,49,46,69,42,38,46,48,53,43,54,37,58,40,38,40,67,22,26,42,45,43,35,49,65,26,56,18,53,69,36,61,43,51,59,43,63,69,36,54,35,66,30,22,51,54,49,41,34,59,20,23,25,63,22,51,49,52,49,44,41,25,51,53,20,30,47,35,41,48,27,26,65,25,19,61,65,23,54,67,41,57,35,57,53,32,23,49,26,62,28,65,56,40,61,35,37,68,44,61,66,53,21,32,46,49,26,40,20,38,63,19,53,51,20,35,62,32,57,49,29,43,36,59,31,51,62,18,52,34,58,51,32,23,38,50,20,26,19,47,56,51,41,61,38,57,62,54,44,29,67,28,34,55,69,38,63,66,68,42,54,41,45,41,34,67,31,52,22,34,25,48,30,36,52,46,65,42,56,68,68,40,18,36
60,66,59,69,47,39,54,67,30,27,52,57,52,20,52,67,20,64,20,60,36,29,45,18,54,45,59,49,61,28,36,69,27,30,67,66,52,69,63,20,23,47,43,55,25,62,23,48,64,50,42,43,25,66,41,37,43,19,64,39,21,51,67,54,21,29,32,55,24,37,53,43,39,37,58,28,45,21,39,23,41,26,51,49,45,33,53,32,40,60,37,56,55,68,54,56,27,41,59,62,32,47,42,33,66,55,24,64,27,62,68,62,36,64,22,26,37,47,40,58,32,36,56,41,34,37,55,25,50,66,52,24,52,43,41,28,31,41,21,45,41,42,50,42,25,39,23,67,42,63,53,32,43,22,30,20,40,61,44,55,54,23,61,37,43,33,18,30,68,34,34,59,22,30,50,68,49,38,51,44,64,31,34,40,58,56,57,38,55,23,66,27,58,32,57,43,56,40,60,41,41,54,42,56,32,59,50,23,50,55,62,32,37,63,18,22,51,52,30,32,46,31,30,24,25,25,31,54,57,25,44,43,18,57,25,50,49,21,38,65,32,47,53,34,61,19,61,33,53,68,37,69,40,67,22,34,34,56 ...

# %% [markdown]
# #### Sales by age group and gender:

# %%
bins = [0, 18, 25, 35, 50, 65, np.inf]
labels = ["Under 18", "18-25", "25-35", "35-50", "50-65", "65+"]
df["age_group"] = pd.cut(df["age"], bins=bins, labels=labels)

sales_by_age_gender = df.groupby(["age_group", "gender"])["price"].sum().reset_index()

fig = px.bar(sales_by_age_gender, x="age_group", y="price", color="gender",
             title="Total Sales by Age Group and Gender",
             labels={"age_group": "Age Group", "price": "Total Sales", "gender": "Gender"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b8d9d434-32d3-4221-a514-88ef54defd19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8d9d434-32d3-4221-a514-88ef54defd19")) {                    Plotly.newPlot(                        "b8d9d434-32d3-4221-a514-88ef54defd19",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Female<br>Age Group=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Under 18","18-25","25-35","35-50","50-65","65+"],"xaxis":"x","y":[720800.22,5580020.14,7769309.7299999995,12051849.62,11806229.09,3003592.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Male<br>Age Group=%{x}<br>Total Sales=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"textposition":"auto","x":["Under 18","18-25","25-35","35-50","50-65","65+"],"xaxis":"x","y":[490663.4,3653288.67,5332046.67,8120121.14,7821513.27,2201931.14],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overla ...

# %% [markdown]
# ## 4. Payment methods

# %% [markdown]
# #### The distribution of payment methods:

# %%
payment_methods = df["payment_method"].value_counts().reset_index()
payment_methods.columns = ["method", "count"]
fig = px.pie(payment_methods, values="count", names="method",
             title="Payment Method Distribution",
             labels={"count": "Count", "method": "Payment Method"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="aeb85ef4-c1a4-4462-86ac-5dd73c707e87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb85ef4-c1a4-4462-86ac-5dd73c707e87")) {                    Plotly.newPlot(                        "aeb85ef4-c1a4-4462-86ac-5dd73c707e87",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Payment Method=%{label}<br>Count=%{value}<extra></extra>","labels":["Cash","Credit Card","Debit Card"],"legendgroup":"","name":"","showlegend":true,"values":[44447,34931,20079],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmo ...
